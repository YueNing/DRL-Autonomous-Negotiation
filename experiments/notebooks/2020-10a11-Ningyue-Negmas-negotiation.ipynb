# %% [markdown]
# ### [Finished] Framework for Negotiation with DRL method under gym environment
# `https://github.com/YueNing/tn_source_code.git`

# %% [markdown]
# ###  [Finished] Learned acceptance network and offer network
#
# 1. [IMRPOVEMENT]: Acceptance Strategy [Finshed] [Single Issue, Multi issues]
#
#     * observation_space = [opponent_offer, time]
#     * action_space = Box.Discrete(3)
#         - ResponseType.ACCEPT,
#         - ResponseType.Wait
#         - ResponseType.REJECT_OFFER
#
# 2. [IMPROEMENT]: Offer Strategy  [Finshed] [Single Issue and Multi issues]
#
#     * observation_space = [opponent_offer, time] normalization between [-1, 1]
#     * action_space = all of outcomes, normalization [-1, 1]

# %% [markdown]
# ### Code example:

# %%
# !pip install negmas==0.7.0
# !pip install scml==0.3.0
# !pip install gym==0.17.2
# Before install stable_baselines Need to install libopenmpi-dev: command 'sudo apt install libopenmpi-dev'
# !pip install mpi4py==3.0.3
# !pip install stable_baselines==2.10.0
# !pip install tensorflow==1.15.3
# !pip install -i https://test.pypi.org/simple/ drl-negotiation
# Out:
# Requirement already satisfied: negmas==0.7.0 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (0.7.0)
# Requirement already satisfied: scipy>=1.2 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas==0.7.0) (1.6.2)
# Requirement already satisfied: sklearn in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas==0.7.0) (0.0)
# Requirement already satisfied: gif in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas==0.7.0) (3.0.0)
# Requirement already satisfied: networkx in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas==0.7.0) (2.5.1)
# Requirement already satisfied: PyYAML in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas==0.7.0) (5.4.1)
# Requirement already satisfied: colorlog in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas==0.7.0) (5.0.1)
# Requirement already satisfied: tqdm>=4.31.1 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas==0.7.0) (4.60.0)
# Requirement already satisfied: progressbar2>=3.39 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas==0.7.0) (3.53.1)
# Requirement already satisfied: inflect in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas==0.7.0) (5.3.0)
# Requirement already satisfied: setuptools>=40.8.0 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas==0.7.0) (52.0.0.post20210125)
# Requirement already satisfied: tabulate in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas==0.7.0) (0.8.9)
# Requirement already satisfied: pytest-runner>=4.4 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas==0.7.0) (5.3.0)
# Requirement already satisfied: pandas>=0.24.1 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas==0.7.0) (1.2.4)
# Requirement already satisfied: typing in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas==0.7.0) (3.7.4.3)
# Requirement already satisfied: py4j in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas==0.7.0) (0.10.9.2)
# Requirement already satisfied: stringcase in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas==0.7.0) (1.2.0)
# Requirement already satisfied: Click>=6.0 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas==0.7.0) (7.1.2)
# Requirement already satisfied: dill in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas==0.7.0) (0.3.3)
# Requirement already satisfied: typing-extensions>=3.7 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas==0.7.0) (3.7.4.3)
# Requirement already satisfied: click-config-file in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas==0.7.0) (0.6.0)
# Requirement already satisfied: matplotlib in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas==0.7.0) (3.4.1)
# Requirement already satisfied: numpy>=1.16 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas==0.7.0) (1.20.2)
# Requirement already satisfied: seaborn in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas==0.7.0) (0.11.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from pandas>=0.24.1->negmas==0.7.0) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from pandas>=0.24.1->negmas==0.7.0) (2021.1)
# Requirement already satisfied: python-utils>=2.3.0 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from progressbar2>=3.39->negmas==0.7.0) (2.5.6)
# Requirement already satisfied: six in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from progressbar2>=3.39->negmas==0.7.0) (1.15.0)
# Requirement already satisfied: configobj>=5.0.6 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from click-config-file->negmas==0.7.0) (5.0.6)
# Requirement already satisfied: Pillow>=7.1.2 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from gif->negmas==0.7.0) (8.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from matplotlib->negmas==0.7.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from matplotlib->negmas==0.7.0) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from matplotlib->negmas==0.7.0) (2.4.7)
# Requirement already satisfied: decorator<5,>=4.3 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from networkx->negmas==0.7.0) (4.4.2)
# Requirement already satisfied: scikit-learn in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from sklearn->negmas==0.7.0) (0.24.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from scikit-learn->sklearn->negmas==0.7.0) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from scikit-learn->sklearn->negmas==0.7.0) (1.0.1)
# Collecting scml==0.3.0
#   Using cached scml-0.3.0-py2.py3-none-any.whl (354 kB)
# Requirement already satisfied: click in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from scml==0.3.0) (7.1.2)
# Collecting pulp
#   Using cached PuLP-2.4-py3-none-any.whl (40.6 MB)
# Requirement already satisfied: joblib in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from scml==0.3.0) (1.0.1)
# Requirement already satisfied: jupyter in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from scml==0.3.0) (1.0.0)
# Collecting prettytable
#   Downloading prettytable-2.1.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: negmas>=0.6.13 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from scml==0.3.0) (0.7.0)
# Requirement already satisfied: gif in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from scml==0.3.0) (3.0.0)
# Requirement already satisfied: tqdm in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from scml==0.3.0) (4.60.0)
# Collecting hypothesis
#   Downloading hypothesis-6.10.0-py3-none-any.whl (364 kB)
#      |████████████████████████████████| 364 kB 8.6 MB/s eta 0:00:01
# Collecting python-constraint
#   Using cached python_constraint-1.4.0-py2.py3-none-any.whl
# Collecting pytest
#   Downloading pytest-6.2.3-py3-none-any.whl (280 kB)
#      |████████████████████████████████| 280 kB 11.1 MB/s eta 0:00:01
# Requirement already satisfied: setuptools>=40.8.0 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas>=0.6.13->scml==0.3.0) (52.0.0.post20210125)
# Requirement already satisfied: dill in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas>=0.6.13->scml==0.3.0) (0.3.3)
# Requirement already satisfied: numpy>=1.16 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas>=0.6.13->scml==0.3.0) (1.20.2)
# Requirement already satisfied: click-config-file in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas>=0.6.13->scml==0.3.0) (0.6.0)
# Requirement already satisfied: pytest-runner>=4.4 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas>=0.6.13->scml==0.3.0) (5.3.0)
# Requirement already satisfied: networkx in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas>=0.6.13->scml==0.3.0) (2.5.1)
# Requirement already satisfied: scipy>=1.2 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas>=0.6.13->scml==0.3.0) (1.6.2)
# Requirement already satisfied: PyYAML in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas>=0.6.13->scml==0.3.0) (5.4.1)
# Requirement already satisfied: py4j in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas>=0.6.13->scml==0.3.0) (0.10.9.2)
# Requirement already satisfied: stringcase in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas>=0.6.13->scml==0.3.0) (1.2.0)
# Requirement already satisfied: inflect in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas>=0.6.13->scml==0.3.0) (5.3.0)
# Requirement already satisfied: tabulate in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas>=0.6.13->scml==0.3.0) (0.8.9)
# Requirement already satisfied: progressbar2>=3.39 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas>=0.6.13->scml==0.3.0) (3.53.1)
# Requirement already satisfied: typing in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas>=0.6.13->scml==0.3.0) (3.7.4.3)
# Requirement already satisfied: seaborn in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas>=0.6.13->scml==0.3.0) (0.11.1)
# Requirement already satisfied: colorlog in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas>=0.6.13->scml==0.3.0) (5.0.1)
# Requirement already satisfied: sklearn in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas>=0.6.13->scml==0.3.0) (0.0)
# Requirement already satisfied: pandas>=0.24.1 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas>=0.6.13->scml==0.3.0) (1.2.4)
# Requirement already satisfied: typing-extensions>=3.7 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas>=0.6.13->scml==0.3.0) (3.7.4.3)
# Requirement already satisfied: matplotlib in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from negmas>=0.6.13->scml==0.3.0) (3.4.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from pandas>=0.24.1->negmas>=0.6.13->scml==0.3.0) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from pandas>=0.24.1->negmas>=0.6.13->scml==0.3.0) (2021.1)
# Requirement already satisfied: python-utils>=2.3.0 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from progressbar2>=3.39->negmas>=0.6.13->scml==0.3.0) (2.5.6)
# Requirement already satisfied: six in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from progressbar2>=3.39->negmas>=0.6.13->scml==0.3.0) (1.15.0)
# Requirement already satisfied: configobj>=5.0.6 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from click-config-file->negmas>=0.6.13->scml==0.3.0) (5.0.6)
# Requirement already satisfied: Pillow>=7.1.2 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from gif->scml==0.3.0) (8.2.0)
# Collecting sortedcontainers<3.0.0,>=2.1.0
#   Using cached sortedcontainers-2.3.0-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: attrs>=19.2.0 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from hypothesis->scml==0.3.0) (20.3.0)
# Requirement already satisfied: nbconvert in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from jupyter->scml==0.3.0) (6.0.7)
# Requirement already satisfied: ipykernel in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from jupyter->scml==0.3.0) (5.5.3)
# Requirement already satisfied: qtconsole in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from jupyter->scml==0.3.0) (5.0.3)
# Requirement already satisfied: jupyter-console in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from jupyter->scml==0.3.0) (6.4.0)
# Requirement already satisfied: notebook in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from jupyter->scml==0.3.0) (6.3.0)
# Requirement already satisfied: ipywidgets in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from jupyter->scml==0.3.0) (7.6.3)
# Requirement already satisfied: ipython>=5.0.0 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from ipykernel->jupyter->scml==0.3.0) (7.22.0)
# Requirement already satisfied: jupyter-client in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from ipykernel->jupyter->scml==0.3.0) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from ipykernel->jupyter->scml==0.3.0) (6.1)
# Requirement already satisfied: traitlets>=4.1.0 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from ipykernel->jupyter->scml==0.3.0) (5.0.5)
# Requirement already satisfied: pexpect>4.3 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->jupyter->scml==0.3.0) (4.8.0)
# Requirement already satisfied: decorator in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->jupyter->scml==0.3.0) (4.4.2)
# Requirement already satisfied: pickleshare in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->jupyter->scml==0.3.0) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->jupyter->scml==0.3.0) (0.18.0)
# Requirement already satisfied: backcall in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->jupyter->scml==0.3.0) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->jupyter->scml==0.3.0) (3.0.18)
# Requirement already satisfied: pygments in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->jupyter->scml==0.3.0) (2.8.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel->jupyter->scml==0.3.0) (0.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from pexpect>4.3->ipython>=5.0.0->ipykernel->jupyter->scml==0.3.0) (0.7.0)
# Requirement already satisfied: wcwidth in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->jupyter->scml==0.3.0) (0.2.5)
# Requirement already satisfied: ipython-genutils in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from traitlets>=4.1.0->ipykernel->jupyter->scml==0.3.0) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from ipywidgets->jupyter->scml==0.3.0) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from ipywidgets->jupyter->scml==0.3.0) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from ipywidgets->jupyter->scml==0.3.0) (5.1.3)
# Requirement already satisfied: jupyter-core in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->scml==0.3.0) (4.7.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->scml==0.3.0) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->scml==0.3.0) (0.17.3)
# Requirement already satisfied: importlib-metadata in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->scml==0.3.0) (4.0.1)
# Requirement already satisfied: argon2-cffi in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from notebook->jupyter->scml==0.3.0) (20.1.0)
# Requirement already satisfied: pyzmq>=17 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from notebook->jupyter->scml==0.3.0) (22.0.3)
# Requirement already satisfied: jinja2 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from notebook->jupyter->scml==0.3.0) (2.11.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from notebook->jupyter->scml==0.3.0) (0.9.4)
# Requirement already satisfied: prometheus-client in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from notebook->jupyter->scml==0.3.0) (0.10.1)
# Requirement already satisfied: Send2Trash>=1.5.0 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from notebook->jupyter->scml==0.3.0) (1.5.0)
# Requirement already satisfied: cffi>=1.0.0 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from argon2-cffi->notebook->jupyter->scml==0.3.0) (1.14.5)
# Requirement already satisfied: pycparser in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from cffi>=1.0.0->argon2-cffi->notebook->jupyter->scml==0.3.0) (2.20)
# Requirement already satisfied: zipp>=0.5 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from importlib-metadata->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->scml==0.3.0) (3.4.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from jinja2->notebook->jupyter->scml==0.3.0) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from matplotlib->negmas>=0.6.13->scml==0.3.0) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from matplotlib->negmas>=0.6.13->scml==0.3.0) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from matplotlib->negmas>=0.6.13->scml==0.3.0) (2.4.7)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from nbconvert->jupyter->scml==0.3.0) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from nbconvert->jupyter->scml==0.3.0) (0.5.3)
# Requirement already satisfied: entrypoints>=0.2.2 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from nbconvert->jupyter->scml==0.3.0) (0.3)
# Requirement already satisfied: defusedxml in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from nbconvert->jupyter->scml==0.3.0) (0.7.1)
# Requirement already satisfied: testpath in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from nbconvert->jupyter->scml==0.3.0) (0.4.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from nbconvert->jupyter->scml==0.3.0) (1.4.3)
# Requirement already satisfied: jupyterlab-pygments in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from nbconvert->jupyter->scml==0.3.0) (0.1.2)
# Requirement already satisfied: bleach in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from nbconvert->jupyter->scml==0.3.0) (3.3.0)
# Requirement already satisfied: nest-asyncio in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->scml==0.3.0) (1.5.1)
# Requirement already satisfied: async-generator in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->scml==0.3.0) (1.10)
# Requirement already satisfied: webencodings in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from bleach->nbconvert->jupyter->scml==0.3.0) (0.5.1)
# Requirement already satisfied: packaging in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from bleach->nbconvert->jupyter->scml==0.3.0) (20.9)
# Collecting amply>=0.1.2
#   Using cached amply-0.1.4-py3-none-any.whl (16 kB)
# Collecting docutils>=0.3
#   Downloading docutils-0.17.1-py2.py3-none-any.whl (575 kB)
#      |████████████████████████████████| 575 kB 8.5 MB/s eta 0:00:01
# Collecting py>=1.8.2
#   Using cached py-1.10.0-py2.py3-none-any.whl (97 kB)
# Collecting iniconfig
#   Using cached iniconfig-1.1.1-py2.py3-none-any.whl (5.0 kB)
# Collecting pluggy<1.0.0a1,>=0.12
#   Using cached pluggy-0.13.1-py2.py3-none-any.whl (18 kB)
# Collecting toml
#   Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: qtpy in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from qtconsole->jupyter->scml==0.3.0) (1.9.0)
# Requirement already satisfied: scikit-learn in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from sklearn->negmas>=0.6.13->scml==0.3.0) (0.24.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from scikit-learn->sklearn->negmas>=0.6.13->scml==0.3.0) (2.1.0)
# Installing collected packages: docutils, toml, sortedcontainers, py, pluggy, iniconfig, amply, python-constraint, pytest, pulp, prettytable, hypothesis, scml
# Successfully installed amply-0.1.4 docutils-0.17.1 hypothesis-6.10.0 iniconfig-1.1.1 pluggy-0.13.1 prettytable-2.1.0 pulp-2.4 py-1.10.0 pytest-6.2.3 python-constraint-1.4.0 scml-0.3.0 sortedcontainers-2.3.0 toml-0.10.2
# Requirement already satisfied: gym==0.17.2 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (0.17.2)
# Requirement already satisfied: scipy in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from gym==0.17.2) (1.6.2)
# Requirement already satisfied: numpy>=1.10.4 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from gym==0.17.2) (1.20.2)
# Requirement already satisfied: cloudpickle<1.4.0,>=1.2.0 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from gym==0.17.2) (1.3.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from gym==0.17.2) (1.5.0)
# Requirement already satisfied: future in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from pyglet<=1.5.0,>=1.4.0->gym==0.17.2) (0.18.2)
# Requirement already satisfied: mpi4py==3.0.3 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (3.0.3)
# Requirement already satisfied: stable_baselines==2.10.0 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (2.10.0)
# Requirement already satisfied: pandas in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from stable_baselines==2.10.0) (1.2.4)
# Requirement already satisfied: opencv-python in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from stable_baselines==2.10.0) (4.5.1.48)
# Requirement already satisfied: gym[atari,classic_control]>=0.11 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from stable_baselines==2.10.0) (0.17.2)
# Requirement already satisfied: matplotlib in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from stable_baselines==2.10.0) (3.4.1)
# Requirement already satisfied: scipy in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from stable_baselines==2.10.0) (1.6.2)
# Requirement already satisfied: joblib in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from stable_baselines==2.10.0) (1.0.1)
# Requirement already satisfied: cloudpickle>=0.5.5 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from stable_baselines==2.10.0) (1.3.0)
# Requirement already satisfied: numpy in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from stable_baselines==2.10.0) (1.20.2)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from gym[atari,classic_control]>=0.11->stable_baselines==2.10.0) (1.5.0)
# Requirement already satisfied: Pillow in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from gym[atari,classic_control]>=0.11->stable_baselines==2.10.0) (8.2.0)
# Requirement already satisfied: atari-py~=0.2.0 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from gym[atari,classic_control]>=0.11->stable_baselines==2.10.0) (0.2.6)
# Requirement already satisfied: six in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from atari-py~=0.2.0->gym[atari,classic_control]>=0.11->stable_baselines==2.10.0) (1.15.0)
# Requirement already satisfied: future in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from pyglet<=1.5.0,>=1.4.0->gym[atari,classic_control]>=0.11->stable_baselines==2.10.0) (0.18.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from matplotlib->stable_baselines==2.10.0) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from matplotlib->stable_baselines==2.10.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from matplotlib->stable_baselines==2.10.0) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from matplotlib->stable_baselines==2.10.0) (2.4.7)
# Requirement already satisfied: pytz>=2017.3 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from pandas->stable_baselines==2.10.0) (2021.1)
# Requirement already satisfied: tensorflow==1.15.3 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (1.15.3)
# Requirement already satisfied: wheel>=0.26 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from tensorflow==1.15.3) (0.36.2)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from tensorflow==1.15.3) (1.1.2)
# Requirement already satisfied: absl-py>=0.7.0 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from tensorflow==1.15.3) (0.12.0)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from tensorflow==1.15.3) (1.15.1)
# Requirement already satisfied: tensorboard<1.16.0,>=1.15.0 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from tensorflow==1.15.3) (1.15.0)
# Requirement already satisfied: astor>=0.6.0 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from tensorflow==1.15.3) (0.8.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from tensorflow==1.15.3) (3.3.0)
# Requirement already satisfied: grpcio>=1.8.6 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from tensorflow==1.15.3) (1.37.0)
# Requirement already satisfied: gast==0.2.2 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from tensorflow==1.15.3) (0.2.2)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from tensorflow==1.15.3) (1.20.2)
# Requirement already satisfied: keras-applications>=1.0.8 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from tensorflow==1.15.3) (1.0.8)
# Requirement already satisfied: wrapt>=1.11.1 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from tensorflow==1.15.3) (1.12.1)
# Requirement already satisfied: google-pasta>=0.1.6 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from tensorflow==1.15.3) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from tensorflow==1.15.3) (1.1.0)
# Requirement already satisfied: protobuf>=3.6.1 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from tensorflow==1.15.3) (3.15.8)
# Requirement already satisfied: six>=1.10.0 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from tensorflow==1.15.3) (1.15.0)
# Requirement already satisfied: h5py in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from keras-applications>=1.0.8->tensorflow==1.15.3) (3.2.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.3) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.3) (52.0.0.post20210125)
# Requirement already satisfied: markdown>=2.6.8 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.3) (3.3.4)
# Requirement already satisfied: importlib-metadata in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.3) (4.0.1)
# Requirement already satisfied: cached-property in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from h5py->keras-applications>=1.0.8->tensorflow==1.15.3) (1.5.2)
# Requirement already satisfied: zipp>=0.5 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from importlib-metadata->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.3) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (from importlib-metadata->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.3) (3.7.4.3)
# Looking in indexes: https://test.pypi.org/simple/
# Requirement already satisfied: drl-negotiation in /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages (0.0.3)

# %% [markdown]
# #### Using DQN to train the Acceptance Strategy of MyDRLNegotiator, competite with the MyOpponentNegotiator

# %%
from drl_negotiation.env import NegotiationEnv
from drl_negotiation.utils import generate_config, genearate_observation_space
from drl_negotiation.game import NegotiationGame
from drl_negotiation.negotiator import MyDRLNegotiator, MyOpponentNegotiator
from drl_negotiation.utility_functions import MyUtilityFunction
from drl_negotiation.train import train_negotiation

config = generate_config(n_issues=1)

game = NegotiationGame(
    name="negotiation_game",
    game_type="DRLNegotiation",
    issues=config.get("issues"),
    competitors=[
        MyDRLNegotiator(
            name="my_drl_negotiator",
            ufun=MyUtilityFunction(weights=config.get("weights")[0]),
            init_proposal=False,
        ),
        MyOpponentNegotiator(
            name="my_opponent_negotiator",
            ufun=MyUtilityFunction(weights=config.get("weights")[1])
        )
    ],
    n_steps=config.get("n_steps")
)
env = NegotiationEnv(
        name="negotiation_env_ac_s",
        strategy="ac_s",
        game=game,
        observation_space=genearate_observation_space(config),
        action_space=3
    )

plot = True

game.set_env(env=env)
model = "DQN"
done, _ = train_negotiation(plot=plot, model=model, num_timesteps=200000, env=env, monitor=False)
assert done,  f'train false by the model {model}'

print('Finished!')
# Out:
# Logging to train_negotiation_DQN
# --------------------------------------
# | % time spent exploring  | 98       |
# | episodes                | 100      |
# | mean 100 episode reward | -0.2     |
# | steps                   | 232      |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 97       |
# | episodes                | 200      |
# | mean 100 episode reward | 0        |
# | steps                   | 485      |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 96       |
# | episodes                | 300      |
# | mean 100 episode reward | 0.1      |
# | steps                   | 736      |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 95       |
# | episodes                | 400      |
# | mean 100 episode reward | 0.3      |
# | steps                   | 993      |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 93       |
# | episodes                | 500      |
# | mean 100 episode reward | 0.3      |
# | steps                   | 1269     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 92       |
# | episodes                | 600      |
# | mean 100 episode reward | 0.2      |
# | steps                   | 1528     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 91       |
# | episodes                | 700      |
# | mean 100 episode reward | 0.3      |
# | steps                   | 1802     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 89       |
# | episodes                | 800      |
# | mean 100 episode reward | -0.1     |
# | steps                   | 2054     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 88       |
# | episodes                | 900      |
# | mean 100 episode reward | 0.3      |
# | steps                   | 2320     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 87       |
# | episodes                | 1000     |
# | mean 100 episode reward | 0.3      |
# | steps                   | 2595     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 85       |
# | episodes                | 1100     |
# | mean 100 episode reward | 0.2      |
# | steps                   | 2866     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 84       |
# | episodes                | 1200     |
# | mean 100 episode reward | 0.4      |
# | steps                   | 3136     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 83       |
# | episodes                | 1300     |
# | mean 100 episode reward | 0.6      |
# | steps                   | 3421     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 81       |
# | episodes                | 1400     |
# | mean 100 episode reward | 0.4      |
# | steps                   | 3704     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 80       |
# | episodes                | 1500     |
# | mean 100 episode reward | 0.9      |
# | steps                   | 4017     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 78       |
# | episodes                | 1600     |
# | mean 100 episode reward | 0.8      |
# | steps                   | 4319     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 77       |
# | episodes                | 1700     |
# | mean 100 episode reward | 0.5      |
# | steps                   | 4598     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 76       |
# | episodes                | 1800     |
# | mean 100 episode reward | 0.7      |
# | steps                   | 4895     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 74       |
# | episodes                | 1900     |
# | mean 100 episode reward | 0.8      |
# | steps                   | 5201     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 72       |
# | episodes                | 2000     |
# | mean 100 episode reward | 1        |
# | steps                   | 5517     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 71       |
# | episodes                | 2100     |
# | mean 100 episode reward | 0.9      |
# | steps                   | 5837     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 69       |
# | episodes                | 2200     |
# | mean 100 episode reward | 0.8      |
# | steps                   | 6144     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 68       |
# | episodes                | 2300     |
# | mean 100 episode reward | 0.7      |
# | steps                   | 6443     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 66       |
# | episodes                | 2400     |
# | mean 100 episode reward | 1        |
# | steps                   | 6765     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 65       |
# | episodes                | 2500     |
# | mean 100 episode reward | 1        |
# | steps                   | 7089     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 63       |
# | episodes                | 2600     |
# | mean 100 episode reward | 1        |
# | steps                   | 7406     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 62       |
# | episodes                | 2700     |
# | mean 100 episode reward | 1.1      |
# | steps                   | 7736     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 60       |
# | episodes                | 2800     |
# | mean 100 episode reward | 1.7      |
# | steps                   | 8116     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 58       |
# | episodes                | 2900     |
# | mean 100 episode reward | 1.6      |
# | steps                   | 8479     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 56       |
# | episodes                | 3000     |
# | mean 100 episode reward | 1.2      |
# | steps                   | 8827     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 54       |
# | episodes                | 3100     |
# | mean 100 episode reward | 1.9      |
# | steps                   | 9210     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 52       |
# | episodes                | 3200     |
# | mean 100 episode reward | 2.1      |
# | steps                   | 9624     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 51       |
# | episodes                | 3300     |
# | mean 100 episode reward | 1.7      |
# | steps                   | 9995     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 48       |
# | episodes                | 3400     |
# | mean 100 episode reward | 2.2      |
# | steps                   | 10420    |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 47       |
# | episodes                | 3500     |
# | mean 100 episode reward | 2.1      |
# | steps                   | 10806    |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 45       |
# | episodes                | 3600     |
# | mean 100 episode reward | 2        |
# | steps                   | 11212    |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 43       |
# | episodes                | 3700     |
# | mean 100 episode reward | 2.1      |
# | steps                   | 11612    |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 40       |
# | episodes                | 3800     |
# | mean 100 episode reward | 2.9      |
# | steps                   | 12086    |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 38       |
# | episodes                | 3900     |
# | mean 100 episode reward | 2.6      |
# | steps                   | 12549    |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 36       |
# | episodes                | 4000     |
# | mean 100 episode reward | 3.1      |
# | steps                   | 13050    |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 33       |
# | episodes                | 4100     |
# | mean 100 episode reward | 3.6      |
# | steps                   | 13585    |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 31       |
# | episodes                | 4200     |
# | mean 100 episode reward | 3        |
# | steps                   | 14063    |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 28       |
# | episodes                | 4300     |
# | mean 100 episode reward | 3.9      |
# | steps                   | 14634    |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 25       |
# | episodes                | 4400     |
# | mean 100 episode reward | 4.3      |
# | steps                   | 15238    |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 21       |
# | episodes                | 4500     |
# | mean 100 episode reward | 6.2      |
# | steps                   | 16033    |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 16       |
# | episodes                | 4600     |
# | mean 100 episode reward | 8.6      |
# | steps                   | 17056    |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 10       |
# | episodes                | 4700     |
# | mean 100 episode reward | 10       |
# | steps                   | 18231    |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 4800     |
# | mean 100 episode reward | 32.5     |
# | steps                   | 22033    |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 4900     |
# | mean 100 episode reward | 44.2     |
# | steps                   | 27290    |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 5000     |
# | mean 100 episode reward | 41       |
# | steps                   | 32066    |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 5100     |
# | mean 100 episode reward | 41.8     |
# | steps                   | 36967    |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 5200     |
# | mean 100 episode reward | 46.2     |
# | steps                   | 42453    |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 5300     |
# | mean 100 episode reward | 42.2     |
# | steps                   | 47415    |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 5400     |
# | mean 100 episode reward | 43.6     |
# | steps                   | 52571    |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 5500     |
# | mean 100 episode reward | 47.9     |
# | steps                   | 58236    |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 5600     |
# | mean 100 episode reward | 40.8     |
# | steps                   | 63082    |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 5700     |
# | mean 100 episode reward | 40.2     |
# | steps                   | 67770    |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 5800     |
# | mean 100 episode reward | 41.9     |
# | steps                   | 72724    |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 5900     |
# | mean 100 episode reward | 41.2     |
# | steps                   | 77497    |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 6000     |
# | mean 100 episode reward | 42       |
# | steps                   | 82410    |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 6100     |
# | mean 100 episode reward | 42.1     |
# | steps                   | 87405    |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 6200     |
# | mean 100 episode reward | 51.6     |
# | steps                   | 93559    |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 6300     |
# | mean 100 episode reward | 38.4     |
# | steps                   | 98030    |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 6400     |
# | mean 100 episode reward | 46.4     |
# | steps                   | 103469   |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 6500     |
# | mean 100 episode reward | 42.6     |
# | steps                   | 108416   |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 6600     |
# | mean 100 episode reward | 43.6     |
# | steps                   | 113579   |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 6700     |
# | mean 100 episode reward | 44.1     |
# | steps                   | 118823   |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 6800     |
# | mean 100 episode reward | 44.7     |
# | steps                   | 124171   |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 6900     |
# | mean 100 episode reward | 46.4     |
# | steps                   | 129684   |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 7000     |
# | mean 100 episode reward | 46.8     |
# | steps                   | 135259   |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 7100     |
# | mean 100 episode reward | 41       |
# | steps                   | 140114   |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 7200     |
# | mean 100 episode reward | 45.3     |
# | steps                   | 145416   |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 7300     |
# | mean 100 episode reward | 48.2     |
# | steps                   | 151109   |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 7400     |
# | mean 100 episode reward | 43.1     |
# | steps                   | 156193   |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 7500     |
# | mean 100 episode reward | 39.1     |
# | steps                   | 160794   |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 7600     |
# | mean 100 episode reward | 46       |
# | steps                   | 166243   |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 7700     |
# | mean 100 episode reward | 43.6     |
# | steps                   | 171374   |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 7800     |
# | mean 100 episode reward | 40.7     |
# | steps                   | 176154   |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 7900     |
# | mean 100 episode reward | 43.3     |
# | steps                   | 181238   |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 8000     |
# | mean 100 episode reward | 45.4     |
# | steps                   | 186573   |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 8100     |
# | mean 100 episode reward | 40.1     |
# | steps                   | 191331   |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 8200     |
# | mean 100 episode reward | 41.2     |
# | steps                   | 196152   |
# --------------------------------------
# Finished!

# %%
# Out:
# '3.7.10 (default, Feb 26 2021, 18:47:35) \n[GCC 7.3.0]'

# %%
from drl_negotiation.utils import generate_action_space
env =  NegotiationEnv(
     name="negotiation_env_of_s",
     strategy="of_s",
     game=game,
     observation_space=genearate_observation_space(config),
     # action_space=[[config.get("issues")[0].values[0], ], [config.get("issues")[0].values[1], ]]
     # action_space=[[-1, ], [1, ]]
     action_space = generate_action_space(config)
)
game.set_env(env=env)
model = "PPO1"
done, _ = train_negotiation(plot=plot, model=model, env=env, monitor=False)
assert done,  f'train false by the model {model}'
# Out:
# Logging to train_negotiation_PPO1
# WARNING:tensorflow:From /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages/stable_baselines/common/distributions.py:418: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /home/naodong2/anaconda3/envs/evaluation/lib/python3.7/site-packages/stable_baselines/ppo1/pposgd_simple.py:163: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# ********** Iteration 0 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00595 |      -0.01420 |       1.91043 |       0.00030 |       1.42033
#      -0.02171 |      -0.01423 |       1.75093 |       0.00297 |       1.42349
#      -0.03408 |      -0.01426 |       1.75034 |       0.01030 |       1.42603
#      -0.04310 |      -0.01428 |       1.76366 |       0.02520 |       1.42807
# Evaluating losses...
#      -0.04480 |      -0.01429 |       1.75554 |       0.03764 |       1.42923
# ----------------------------------
# | EpLenMean       | 6.15         |
# | EpRewMean       | 1.02         |
# | EpThisIter      | 39           |
# | EpisodesSoFar   | 39           |
# | TimeElapsed     | 0.583        |
# | TimestepsSoFar  | 256          |
# | ev_tdlam_before | 0.00744      |
# | loss_ent        | 1.4292327    |
# | loss_kl         | 0.037637867  |
# | loss_pol_entpen | -0.014292327 |
# | loss_pol_surr   | -0.04479905  |
# | loss_vf_loss    | 1.7555395    |
# ----------------------------------
# ********** Iteration 1 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00694 |      -0.01430 |       2.42997 |       0.00053 |       1.42961
#      -0.01998 |      -0.01430 |       2.23054 |       0.00631 |       1.43008
#      -0.02767 |      -0.01430 |       2.04322 |       0.01965 |       1.42973
#      -0.02773 |      -0.01429 |       1.92718 |       0.03490 |       1.42915
# Evaluating losses...
#      -0.02635 |      -0.01429 |       1.89548 |       0.04256 |       1.42895
# ----------------------------------
# | EpLenMean       | 7.49         |
# | EpRewMean       | 1.38         |
# | EpThisIter      | 28           |
# | EpisodesSoFar   | 67           |
# | TimeElapsed     | 0.96         |
# | TimestepsSoFar  | 512          |
# | ev_tdlam_before | 0.0254       |
# | loss_ent        | 1.4289533    |
# | loss_kl         | 0.042562295  |
# | loss_pol_entpen | -0.014289533 |
# | loss_pol_surr   | -0.026350968 |
# | loss_vf_loss    | 1.8954806    |
# ----------------------------------
# ********** Iteration 2 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00265 |      -0.01429 |      10.74386 |       0.00015 |       1.42876
#      -0.01036 |      -0.01428 |       9.91711 |       0.00231 |       1.42795
#      -0.01228 |      -0.01427 |       9.03876 |       0.00766 |       1.42684
#      -0.01208 |      -0.01426 |       8.19442 |       0.01405 |       1.42563
# Evaluating losses...
#      -0.01163 |      -0.01425 |       7.72517 |       0.01512 |       1.42473
# ----------------------------------
# | EpLenMean       | 9.38         |
# | EpRewMean       | 2.37         |
# | EpThisIter      | 14           |
# | EpisodesSoFar   | 81           |
# | TimeElapsed     | 1.33         |
# | TimestepsSoFar  | 768          |
# | ev_tdlam_before | 0.0419       |
# | loss_ent        | 1.4247341    |
# | loss_kl         | 0.015123211  |
# | loss_pol_entpen | -0.014247341 |
# | loss_pol_surr   | -0.011630055 |
# | loss_vf_loss    | 7.7251687    |
# ----------------------------------
# ********** Iteration 3 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00079 |      -0.01424 |      14.76209 |      2.34e-05 |       1.42440
#      -0.00412 |      -0.01424 |      14.11220 |       0.00036 |       1.42354
#      -0.00503 |      -0.01423 |      13.47855 |       0.00095 |       1.42282
#      -0.00483 |      -0.01422 |      12.87874 |       0.00101 |       1.42220
# Evaluating losses...
#      -0.00523 |      -0.01422 |      12.49195 |       0.00086 |       1.42186
# -----------------------------------
# | EpLenMean       | 10            |
# | EpRewMean       | 3.04          |
# | EpThisIter      | 18            |
# | EpisodesSoFar   | 99            |
# | TimeElapsed     | 1.7           |
# | TimestepsSoFar  | 1024          |
# | ev_tdlam_before | 0.115         |
# | loss_ent        | 1.4218554     |
# | loss_kl         | 0.0008631181  |
# | loss_pol_entpen | -0.014218554  |
# | loss_pol_surr   | -0.0052281246 |
# | loss_vf_loss    | 12.49195      |
# -----------------------------------

# %% [markdown]
# ### Example result shown in tensorboard
#
# Episode reward: The reward of Acceptance strategy  and offer/bidding strategy is increasing.

# %% [markdown]
# #### SIgnle issue, acceptance strategy, episode reward, dqn(blue line) and ppo1(pink line)
#
# ![single issue](./single_issue_negotiation/ac_s_dqn_ppo1_EpRe.svg)
#
# #### SIgnle issue, offer/bidding strategy, episode reward, ppo1
#
# ![single issue](./single_issue_negotiation/of_s_ppo1_EpRe.svg)

# %% [markdown]
# The basic environment of negotiation with method deep reinforcement learning has been implemented!
#
# The future work is about implementing a scml environment as similar as negotiation environment.
#
# Due to the many ideas of improvement of agents in scml. can not try all parts.
# The future work (myagent in scml) is mainly in **negotiation manager** and **negotiation algorithm**.
